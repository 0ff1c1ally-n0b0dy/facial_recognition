# %%
#####################
#FB and GOOG face recognition combined (most kept from FB and included some ideas from GOOG).
#FB
#Facebook transformer for image classification: https://github.com/facebookresearch/deit/blob/main/models_v2.py
#Go to line 269 for examples for different models with different inputs.
#The paper with details on learning rate, optimizer type etc is: https://arxiv.org/pdf/2012.12877.pdf
#GOOG
#Google transformer for image classification: https://github.com/rwightman/pytorch-image-models/blob/master/timm/models/vision_transformer.py
#The paper is at the following link: https://arxiv.org/pdf/2010.11929.pdf
#Implementation that generalizes Layer_scale_init_Block and adds ScaledLayers, following Google's idea for ParallelBlock.
#####################
from torch import nn, optim, as_tensor
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F
from torch.optim import lr_scheduler
from torch.nn.init import *
from torchvision import transforms, utils, datasets, models
import cv2
from PIL import Image
from pdb import set_trace
import time
import copy
from pathlib import Path
import os
import sys
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from skimage import io, transform
from tqdm import trange, tqdm
import csv 
import glob 
import dlib
import pandas as pd
import numpy as np
from functools import partial
from collections import OrderedDict
from timm.models.vision_transformer import Mlp, PatchEmbed , _cfg
from timm.models.layers import DropPath, to_2tuple, trunc_normal_
from timm.models.registry import register_model


#Imports inside facenet scripts that need to be loaded here on google colab.
import requests
from requests.adapters import HTTPAdapter
import torch
import hashlib
import shutil
import tempfile
from urllib.request import urlopen, Request

device = 'cuda:0' if torch.cuda.is_available() else 'cpu'
print(f'Running on device: {device}')

#####################
#Global valriables
####################
#The following variable determines how many pictures are fed at once into the NN (this is made for speed). 
#Facebook does 4096.
batches=32   
#The following path points to the folder that contains the images with faces only.
data_dir=r"C:\Users\mihnea.andrei\Python scripts\resnet_andrei\images_faces"

def imshow(inp,title=None):
  ############
  #Imshow for tensor
  #############
    inp=inp.numpy().transpose([1,2,0])
    mean=np.array([0.485, 0.456, 0.406])
    std=np.array([0.229, 0.224, 0.225])
    inp=std*inp+mean
    inp=np.clip(inp,0,1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.0001)

#The following function times the NN.
def timming(since):
    time_elapsed=time.time()-since
    minutes=time_elapsed // 60
    seconds=time_elapsed%60
    return "%d m:%d s"%(minutes,seconds)
# Out:
# Running on device: cpu

# %%
#If you use the MTCNN code that does the random transformations also, you do not need all those transformations again 
#(maybe) except the horizonta flip - the angle from which the picture is taken.
data_transforms={
    'train': transforms.Compose([
        transforms.RandomHorizontalFlip(p=0.5),  
        #transforms.ColorJitter(brightness=0.5,contrast=0.5),
        #transforms.GaussianBlur(kernel_size=(5, 9), sigma=(3, 7)),
        #transforms.RandomAdjustSharpness(sharpness_factor=15),
        transforms.ToTensor(),
        transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))
    ]),
    'eval': transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))
    ])
}
phases=list(data_transforms.keys())
image_datasets={x:datasets.ImageFolder(os.path.join(data_dir,x),data_transforms[x]) for x in list(data_transforms.keys())}
dataloaders={x:torch.utils.data.DataLoader(image_datasets[x],batch_size=batches,shuffle=True) for x in list(data_transforms.keys())}
data_sizes={x:len(image_datasets[x]) for x in list(data_transforms.keys())}
class_names=image_datasets['train'].classes 

inputs, classes = next(iter(dataloaders['train']))
out=utils.make_grid(inputs)
imshow(out,title=",".join([class_names[i] for i in classes.tolist()]))

# %%
#Attention from FB 
class Attention(nn.Module):
    # taken from https://github.com/rwightman/pytorch-image-models/blob/master/timm/models/vision_transformer.py
    def __init__(self, dim, num_heads=8, qkv_bias=False, qk_scale=None, attn_drop=0., proj_drop=0.):
        super().__init__()
        self.num_heads = num_heads
        head_dim = dim // num_heads
        self.scale = qk_scale or head_dim ** -0.5

        self.qkv = nn.Linear(dim, dim * 3, bias=qkv_bias)
        self.attn_drop = nn.Dropout(attn_drop)
        self.proj = nn.Linear(dim, dim)
        self.proj_drop = nn.Dropout(proj_drop)

    def forward(self, x):
        B, N, C = x.shape
        qkv = self.qkv(x).reshape(B, N, 3, self.num_heads, C // self.num_heads).permute(2, 0, 3, 1, 4)
        q, k, v = qkv[0], qkv[1], qkv[2]
        
        q = q * self.scale

        attn = (q @ k.transpose(-2, -1))
        attn = attn.softmax(dim=-1)
        attn = self.attn_drop(attn)

        x = (attn @ v).transpose(1, 2).reshape(B, N, C)
        x = self.proj(x)
        x = self.proj_drop(x)
        return x

# %%
#LayerScale from Google
class LayerScale(nn.Module):
    def __init__(self, dim, init_values=1e-5, inplace=False):
        super().__init__()
        self.inplace = inplace
        self.gamma = nn.Parameter(init_values * torch.ones(dim))

    def forward(self, x):
        return x.mul_(self.gamma) if self.inplace else x * self.gamma

# %%
#Original Block class from FB to which I try to add the extra layers that Google has
#Can be passed to block_layers parameter in main class.
class Block(nn.Module):
    # taken from https://github.com/rwightman/pytorch-image-models/blob/master/timm/models/vision_transformer.py
    def __init__(self, dim, num_heads, mlp_ratio=4., qkv_bias=False, qk_scale=None, drop=0., attn_drop=0.,
                 drop_path=0., act_layer=nn.GELU, norm_layer=nn.LayerNorm,Attention_block = Attention,Mlp_block=Mlp
                 ,init_values=1e-4):
        super().__init__()
        self.norm1 = norm_layer(dim)
        self.attn = Attention_block(
            dim, num_heads=num_heads, qkv_bias=qkv_bias, qk_scale=qk_scale, attn_drop=attn_drop, proj_drop=drop)
        # NOTE: drop path for stochastic depth, we shall see if this is better than dropout here
        #Below, I add the LayerScale that Google has.
        self.ls1=LayerScale(dim,init_values=init_values) if init_values else nn.Identity()
        self.drop_path1 = DropPath(drop_path) if drop_path > 0. else nn.Identity()
        
        self.norm2 = norm_layer(dim)
        mlp_hidden_dim = int(dim * mlp_ratio)
        self.mlp = Mlp_block(in_features=dim, hidden_features=mlp_hidden_dim, act_layer=act_layer, drop=drop)
        #Below I add another LayerScale that Google has
        self.ls2=LayerScale(dim,init_values=init_values) if init_values else nn.Identity()
        self.drop_path2 = DropPath(drop_path) if drop_path > 0. else nn.Identity()
        

    def forward(self, x):
        x = x + self.drop_path1(self.ls1(self.attn(self.norm1(x))))
        x = x + self.drop_path2(self.ls2(self.mlp(self.norm2(x))))
        return x

# %%
#Take class from below from FB     
#Can be passed to block_layers parameter in main class.
class Layer_scale_init_Block(nn.Module):
    # taken from https://github.com/rwightman/pytorch-image-models/blob/master/timm/models/vision_transformer.py
    # with slight modifications
    def __init__(self, dim, num_heads, mlp_ratio=4., qkv_bias=False, qk_scale=None, drop=0., attn_drop=0.,
                 drop_path=0., act_layer=nn.GELU, norm_layer=nn.LayerNorm,Attention_block = Attention,Mlp_block=Mlp
                 ,init_values=1e-4):
        super().__init__()
        self.norm1 = norm_layer(dim)
        self.attn = Attention_block(
            dim, num_heads=num_heads, qkv_bias=qkv_bias, qk_scale=qk_scale, attn_drop=attn_drop, proj_drop=drop)
        # NOTE: drop path for stochastic depth, we shall see if this is better than dropout here
        self.drop_path = DropPath(drop_path) if drop_path > 0. else nn.Identity()
        self.norm2 = norm_layer(dim)
        mlp_hidden_dim = int(dim * mlp_ratio)
        self.mlp = Mlp_block(in_features=dim, hidden_features=mlp_hidden_dim, act_layer=act_layer, drop=drop)
        self.gamma_1 = nn.Parameter(init_values * torch.ones((dim)),requires_grad=True)
        self.gamma_2 = nn.Parameter(init_values * torch.ones((dim)),requires_grad=True)

    def forward(self, x):
        x = x + self.drop_path(self.gamma_1 * self.attn(self.norm1(x)))
        x = x + self.drop_path(self.gamma_2 * self.mlp(self.norm2(x)))
        return x

# %%
#Can be passed to block_layers parameter in main class.
#Implementation that generalizes Layer_scale_init_Block following Google's idea for ParallelBlock.
class ParallelLayer_scale_init_Block(nn.Module):
    def __init__(self,dim,num_heads,mlp_ratio=4,qkv_bias=False,qk_scale=None,drop=0,attn_drop=0,
                drop_path=0,act_layer=nn.GELU,norm_layer=nn.LayerNorm,Attention_block=Attention,
                 Mlp_block=Mlp,init_values=10**(-4),num_parallel=2):
        super().__init__()
        self.num_parallel=num_parallel
        self.attns=nn.ModuleList()
        self.ffns=nn.ModuleList()
        #####################3
        #do not know how to multiply by gammas since those are just compositions of functions basically.
        #hopefully it does not matter since gammas are parameters and maybe it will be better if num_parameters>2
        #could add LayerScale to both attention and forward feed.
        ############################
        mlp_hidden_dim = int(dim * mlp_ratio)
        for _ in range(num_parallel):
            self.attns.append(nn.Sequential(OrderedDict([
                ("norm",norm_layer(dim)),
                ("attn",Attention_block(dim,num_heads=num_heads,qkv_bias=qkv_bias,qk_scale=qk_scale,
                                   attn_drop=attn_drop,proj_drop=drop)),
                ("ls",LayerScale(dim,init_values=init_values) if init_values else nn.Identity()),
                ("drop_path",DropPath(drop_path) if drop_path>0 else nn.Identity())
            ])))
            self.ffns.append(nn.Sequential(OrderedDict([
                ("norm",norm_layer(dim)),
                ("mlp",Mlp_block(in_features=dim,hidden_features=mlp_hidden_dim,act_layer=act_layer,drop=drop)),
                ("ls",LayerScale(dim,init_values=init_values) if init_values else nn.Identity()),
                ("drop_path",DropPath(drop_path) if drop_path>0 else nn.Identity())
            ])))
    
    def forward(self,x):
        x=x+torch.stack([attn(x) for attn in self.attns]).sum(dim=0)
        x=x+torch.stack([ffn(x) for ffn in self.ffns]).sum(dim=0)
        return x

# %%
#Use the generalized implementation that Google has for FB's Block_paralx2 (num_parallel=2 here for FB's implementation).
#Can be passed to block_layers parameter in main class.
class ParallelBlock(nn.Module):
    def __init__(self,dim,num_heads,num_parallel=2,mlp_ratio=4,qkv_bias=False,qk_scale=None,init_values=10**(-4),
                 drop=0,attn_drop=0,drop_path=0,act_layer=nn.GELU,norm_layer=nn.LayerNorm,Attention_block=Attention,
                 Mlp_block=Mlp):
        super().__init__()
        self.num_parallel=num_parallel
        self.attns=nn.ModuleList()
        self.ffns=nn.ModuleList()
        for _ in range(num_parallel):
            self.attns.append(nn.Sequential(OrderedDict([
                ("norm",norm_layer(dim)),
                ("attn",Attention(dim,num_heads=num_heads,qkv_bias=qkv_bias,qk_scale=qk_scale,attn_drop=attn_drop,proj_drop=drop)),
                ("ls",LayerScale(dim,init_values=init_values) if init_values else nn.Identity()),
                ("drop_path",DropPath(drop_path) if drop_path>0 else nn.Identity()) 
            ])))
            self.ffns.append(nn.Sequential(OrderedDict([
                ("norm",norm_layer(dim)),
                ("mlp",Mlp(dim,hidden_features=int(dim*mlp_ratio),act_layer=act_layer,drop=drop)),
                ("ls",LayerScale(dim,init_values=init_values) if init_values else nn.Identity()),
                ("drop_path", DropPath(drop_path) if drop_path>0 else nn.Identity())
            ])))
    def _forward_jit(self,x):
        x=x+torch.stack([attn(x) for attn in self.attns]).sum(dim=0)
        x=x+torch.stack([ffn(x) for ffn in self.ffns]).sum(dim=0)
        return x
                               
    #@torch.jit.ignore
    def forward(self,x):
        return self._forward_jit(x)

# %%
#Copy class from below from FB
class hMLP_stem(nn.Module):
    """ hMLP_stem: https://arxiv.org/pdf/2203.09795.pdf
    taken from https://github.com/rwightman/pytorch-image-models/blob/master/timm/models/vision_transformer.py
    with slight modifications
    """
    def __init__(self, img_size=224,  patch_size=16, in_chans=3, embed_dim=768,norm_layer=nn.SyncBatchNorm):
        super().__init__()
        img_size = to_2tuple(img_size)
        patch_size = to_2tuple(patch_size)
        num_patches = (img_size[1] // patch_size[1]) * (img_size[0] // patch_size[0])
        self.img_size = img_size
        self.patch_size = patch_size
        self.num_patches = num_patches
        self.proj = torch.nn.Sequential(*[nn.Conv2d(in_chans, embed_dim//4, kernel_size=4, stride=4),
                                          norm_layer(embed_dim//4),
                                          nn.GELU(),
                                          nn.Conv2d(embed_dim//4, embed_dim//4, kernel_size=2, stride=2),
                                          norm_layer(embed_dim//4),
                                          nn.GELU(),
                                          nn.Conv2d(embed_dim//4, embed_dim, kernel_size=2, stride=2),
                                          norm_layer(embed_dim),
                                         ])
        

    def forward(self, x):
        B, C, H, W = x.shape
        x = self.proj(x).flatten(2).transpose(1, 2)
        return x

# %%
#Copy class from below from FB
class vit_models(nn.Module):
    """ Vision Transformer with LayerScale (https://arxiv.org/abs/2103.17239) support
    taken from https://github.com/rwightman/pytorch-image-models/blob/master/timm/models/vision_transformer.py
    with slight modifications
    """
    def __init__(self, img_size=224,  patch_size=16, in_chans=3, num_classes=1000, embed_dim=768, depth=12,
                 num_heads=12, mlp_ratio=4., qkv_bias=False, qk_scale=None, drop_rate=0., attn_drop_rate=0.,
                 drop_path_rate=0., norm_layer=nn.LayerNorm, global_pool=None,
                 block_layers = Block,
                 Patch_layer=PatchEmbed,act_layer=nn.GELU,
                 Attention_block = Attention, Mlp_block=Mlp,
                dpr_constant=True,init_scale=1e-4,
                mlp_ratio_clstk = 4.0):
        super().__init__()
        
        self.dropout_rate = drop_rate

            
        self.num_classes = num_classes
        self.num_features = self.embed_dim = embed_dim

        self.patch_embed = Patch_layer(
                img_size=img_size, patch_size=patch_size, in_chans=in_chans, embed_dim=embed_dim)
        num_patches = self.patch_embed.num_patches

        self.cls_token = nn.Parameter(torch.zeros(1, 1, embed_dim))

        self.pos_embed = nn.Parameter(torch.zeros(1, num_patches, embed_dim))

        dpr = [drop_path_rate for i in range(depth)]
        self.blocks = nn.ModuleList([
            block_layers(
                dim=embed_dim, num_heads=num_heads, mlp_ratio=mlp_ratio, qkv_bias=qkv_bias, qk_scale=qk_scale,
                drop=0.0, attn_drop=attn_drop_rate, drop_path=dpr[i], norm_layer=norm_layer,
                act_layer=act_layer,Attention_block=Attention_block,Mlp_block=Mlp_block,init_values=init_scale)
            for i in range(depth)])
        

        
            
        self.norm = norm_layer(embed_dim)

        self.feature_info = [dict(num_chs=embed_dim, reduction=0, module='head')]
        self.head = nn.Linear(embed_dim, num_classes) if num_classes > 0 else nn.Identity()

        trunc_normal_(self.pos_embed, std=.02)
        trunc_normal_(self.cls_token, std=.02)
        self.apply(self._init_weights)

    def _init_weights(self, m):
        if isinstance(m, nn.Linear):
            trunc_normal_(m.weight, std=.02)
            if isinstance(m, nn.Linear) and m.bias is not None:
                nn.init.constant_(m.bias, 0)
        elif isinstance(m, nn.LayerNorm):
            nn.init.constant_(m.bias, 0)
            nn.init.constant_(m.weight, 1.0)

    @torch.jit.ignore
    def no_weight_decay(self):
        return {'pos_embed', 'cls_token'}

    def get_classifier(self):
        return self.head
    
    def get_num_layers(self):
        return len(self.blocks)
    
    def reset_classifier(self, num_classes, global_pool=''):
        self.num_classes = num_classes
        self.head = nn.Linear(self.embed_dim, num_classes) if num_classes > 0 else nn.Identity()

    def forward_features(self, x):
        B = x.shape[0]
        x = self.patch_embed(x)

        cls_tokens = self.cls_token.expand(B, -1, -1)
        
        x = x + self.pos_embed
        
        x = torch.cat((cls_tokens, x), dim=1)
            
        for i , blk in enumerate(self.blocks):
            x = blk(x)
            
        x = self.norm(x)
        return x[:, 0]

    def forward(self, x):

        x = self.forward_features(x)
        
        if self.dropout_rate:
            x = F.dropout(x, p=float(self.dropout_rate), training=self.training)
        x = self.head(x)
        
        return x

# %%
#The below number is 160 because the faces extracted by MTCNN are 160x160.
img_size=160
#The number of names that the model will see (population of romania over 14).
num_classes=data_sizes["train"]
#Variables inside the network. Please check examples that start at line 271 here: 
#https://github.com/facebookresearch/deit/blob/main/models_v2.py
embed_dim=192
depth=12
num_heads=3
mlp_ratio=4

model_fit=vit_models(num_classes=num_classes,img_size=img_size,patch_size=batches,
                     embed_dim=embed_dim,depth=depth,num_heads=num_heads,mlp_ratio=mlp_ratio,qkv_bias=True,
                    norm_layer=partial(nn.LayerNorm,eps=10**(-6)),
                    block_layers=Layer_scale_init_Block).to(device)

num_epochs=25
lr=3*10**(-3)
weight_decay=0.01
criterion=nn.CrossEntropyLoss()
#Facebook does AdamW. Please see paper.
#optimizer=optim.SGD(model_fit.parameters(),lr=10**(-2),momentum=0.9)
optimizer=torch.optim.AdamW(model_fit.parameters(),lr=lr, betas=(0.9, 0.999), eps=1e-08, weight_decay=weight_decay)
#lr_decay=lr_scheduler.StepLR(optimizer,step_size=7,gamma=0.1)
lr_decay=torch.optim.lr_scheduler.CosineAnnealingLR(optimizer=optimizer, T_max=num_epochs)

# %%
best_model_weights=copy.deepcopy(model_fit.state_dict())
best_acc=0
since=time.time()
printing_iter=10**(1)

for epoch in range(num_epochs):
    print("-"*100)
    print("Training for epoch %d/%d started"%(epoch+1,num_epochs))
    print("-"*100)
    
    train_losses=[]
    train_accs=[]
    counter=0

    for x, label in dataloaders["train"]:
        x=x.to(device)
        label=label.to(device)
        
        optimizer.zero_grad()
        
        output=model_fit(x)
        loss=criterion(output,label)
        
        output=torch.exp(output)
        _, pred=output.topk(1,dim=1)
        
        loss.backward()
        optimizer.step()
        lr_decay.step()
        
        last_loss=loss.item()
        train_losses.append(last_loss)    
        last_acc=torch.sum(pred==label.data).double()
        train_accs.append(last_acc)

        counter+=1
        if counter%printing_iter==0:
            print("Train completion:%.2f%%, time:%s, avg loss: %.2f, avg acc:%.2f%%, last loss: %.2f"
                  %(100*counter*batches/data_sizes["train"],timming(since),np.mean(train_losses),
                    100*np.mean(train_accs),last_loss))
    
    training_avg_loss=np.mean(train_losses)
    training_avg_accuracy=100*np.mean(train_accs)
    print("-"*100)
    print("Eval for epoch %d/%d started"%(epoch+1,num_epochs))
    print("-"*100)
    
    since=time.time()
    counter=0
    eval_losses=[]
    eval_accs=[]
    
    with torch.no_grad():
        for x, label in dataloaders["eval"]:
            
            output=model_fit(x)
            loss=criterion(output,label)
            
            output=torch.exp(output)
            _, pred=output.topk(1,dim=1)
            
            
            last_loss=loss.item()
            eval_losses.append(last_loss)
            last_acc=torch.sum(pred==label.data).double()
            eval_accs.append(last_acc)
            
            counter+=1
            if counter%printing_iter==0:
                print("Eval completion:%.2f%%, time:%s, avg loss: %.2f, avg acc:%.2f%%, last loss: %.2f"
                      %(100*counter*batches/data_sizes["eval"],timming(since),np.mean(eval_losses),
                        100*np.mean(eval_accs),last_loss))
            
    eval_avg_loss=np.mean(eval_losses)
    eval_avg_acc=100*np.mean(eval_accs)
    
    print("-"*100)
    print("Completed epoch %d/%d in %s, avg train loss: %.2f, avg train acc: %.2f%%, avg eval loss: %.2f, avg eval acc: %.2f"%
          (epoch+1,num_epochs,timming(since),training_avg_loss,training_avg_accuracy,eval_avg_loss,eval_avg_acc))
    print("-"*100)
# Out:
# ----------------------------------------------------------------------------------------------------
#
# Train completion:1.25%, time:6 m:59 s, avg loss: 13.42, avg acc:0.00%, last loss: 13.47
# Train completion:1.30%, time:7 m:14 s, avg loss: 13.42, avg acc:0.00%, last loss: 13.46
# Train completion:1.34%, time:7 m:29 s, avg loss: 13.42, avg acc:0.00%, last loss: 13.20
# Train completion:1.39%, time:7 m:44 s, avg loss: 13.42, avg acc:0.00%, last loss: 13.31
# Train completion:1.43%, time:7 m:59 s, avg loss: 13.41, avg acc:0.00%, last loss: 13.13
# Train completion:1.48%, time:8 m:15 s, avg loss: 13.41, avg acc:0.00%, last loss: 13.50
# Train completion:1.52%, time:8 m:30 s, avg loss: 13.41, avg acc:0.00%, last loss: 13.22
# Train completion:1.57%, time:8 m:45 s, avg loss: 13.40, avg acc:0.00%, last loss: 13.42
# Train completion:1.61%, time:9 m:0 s, avg loss: 13.40, avg acc:0.00%, last loss: 13.24
# Train completion:1.66%, time:9 m:15 s, avg loss: 13.40, avg acc:0.27%, last loss: 13.20
# Train completion:1.70%, time:9 m:30 s, avg loss: 13.39, avg acc:0.26%, last loss: 13.42
# Train completion:1.74%, time:9 m:46 s, avg loss: 13.39, avg acc:0.26%, last loss: 12.93
# Train completion:1.79%, time:10 m:1 s, avg loss: 13.39, avg acc:0.25%, last loss: 13.61
# Train completion:1.83%, time:10 m:16 s, avg loss: 13.39, avg acc:0.24%, last loss: 13.41
# Train completion:1.88%, time:10 m:31 s, avg loss: 13.39, avg acc:0.24%, last loss: 13.17
# Train completion:1.92%, time:10 m:47 s, avg loss: 13.39, avg acc:0.23%, last loss: 13.43
# Train completion:1.97%, time:11 m:2 s, avg loss: 13.38, avg acc:0.23%, last loss: 13.31
# Train completion:2.01%, time:11 m:17 s, avg loss: 13.38, avg acc:0.22%, last loss: 13.22
# Train completion:2.06%, time:11 m:33 s, avg loss: 13.38, avg acc:0.22%, last loss: 13.29
# Train completion:2.10%, time:11 m:48 s, avg loss: 13.37, avg acc:0.21%, last loss: 13.33
# Train completion:2.15%, time:12 m:5 s, avg loss: 13.37, avg acc:0.21%, last loss: 13.20
# Train completion:2.19%, time:12 m:20 s, avg loss: 13.37, avg acc:0.20%, last loss: 13.28
# Train completion:2.24%, time:12 m:35 s, avg loss: 13.37, avg acc:0.20%, last loss: 13.25
# Train completion:2.28%, time:12 m:51 s, avg loss: 13.36, avg acc:0.20%, last loss: 13.13
# Train completion:2.33%, time:13 m:6 s, avg loss: 13.36, avg acc:0.19%, last loss: 13.12
# Train completion:2.37%, time:13 m:21 s, avg loss: 13.36, avg acc:0.19%, last loss: 13.31
# Train completion:2.42%, time:13 m:36 s, avg loss: 13.35, avg acc:0.19%, last loss: 13.30
# Train completion:2.46%, time:13 m:52 s, avg loss: 13.35, avg acc:0.18%, last loss: 13.13
# Train completion:2.51%, time:14 m:7 s, avg loss: 13.35, avg acc:0.18%, last loss: 13.46
# Train completion:2.55%, time:14 m:22 s, avg loss: 13.34, avg acc:0.18%, last loss: 13.14
# Train completion:2.59%, time:14 m:37 s, avg loss: 13.34, avg acc:0.17%, last loss: 13.59
# Train completion:4.03%, time:22 m:55 s, avg loss: 13.25, avg acc:0.11%, last loss: 12.87
# Train completion:4.07%, time:23 m:11 s, avg loss: 13.25, avg acc:0.11%, last loss: 12.74
# Train completion:4.12%, time:23 m:26 s, avg loss: 13.24, avg acc:0.11%, last loss: 12.91
# Train completion:4.16%, time:23 m:41 s, avg loss: 13.24, avg acc:0.11%, last loss: 13.12
# Train completion:4.21%, time:23 m:57 s, avg loss: 13.24, avg acc:0.11%, last loss: 13.30
# Train completion:4.25%, time:24 m:12 s, avg loss: 13.24, avg acc:0.11%, last loss: 12.85
# Train completion:4.29%, time:24 m:28 s, avg loss: 13.23, avg acc:0.10%, last loss: 13.10
# Train completion:4.34%, time:24 m:43 s, avg loss: 13.23, avg acc:0.10%, last loss: 12.60
# Train completion:4.38%, time:24 m:59 s, avg loss: 13.23, avg acc:0.10%, last loss: 13.13
# Train completion:4.43%, time:25 m:15 s, avg loss: 13.22, avg acc:0.10%, last loss: 12.93
# Train completion:4.47%, time:25 m:30 s, avg loss: 13.22, avg acc:0.10%, last loss: 12.93
# Train completion:4.52%, time:25 m:45 s, avg loss: 13.22, avg acc:0.10%, last loss: 13.32
# Train completion:4.56%, time:26 m:1 s, avg loss: 13.22, avg acc:0.10%, last loss: 13.17
# Train completion:4.61%, time:26 m:17 s, avg loss: 13.21, avg acc:0.10%, last loss: 12.84
# Train completion:4.65%, time:26 m:32 s, avg loss: 13.21, avg acc:0.10%, last loss: 12.76
# Train completion:4.70%, time:26 m:48 s, avg loss: 13.21, avg acc:0.10%, last loss: 13.08
# Train completion:4.74%, time:27 m:3 s, avg loss: 13.21, avg acc:0.09%, last loss: 13.25
# Train completion:4.79%, time:27 m:19 s, avg loss: 13.20, avg acc:0.09%, last loss: 12.96
# Train completion:4.83%, time:27 m:34 s, avg loss: 13.20, avg acc:0.09%, last loss: 12.95
# Train completion:4.88%, time:27 m:50 s, avg loss: 13.20, avg acc:0.09%, last loss: 13.38
# Train completion:4.92%, time:28 m:5 s, avg loss: 13.20, avg acc:0.09%, last loss: 12.82
# Train completion:4.97%, time:28 m:21 s, avg loss: 13.19, avg acc:0.09%, last loss: 12.63
# Train completion:5.01%, time:28 m:36 s, avg loss: 13.19, avg acc:0.09%, last loss: 13.35
# Train completion:5.06%, time:28 m:52 s, avg loss: 13.19, avg acc:0.09%, last loss: 12.58
# Train completion:5.10%, time:29 m:7 s, avg loss: 13.18, avg acc:0.09%, last loss: 12.72
# Train completion:5.14%, time:29 m:23 s, avg loss: 13.18, avg acc:0.09%, last loss: 12.89
# Train completion:5.19%, time:29 m:38 s, avg loss: 13.18, avg acc:0.09%, last loss: 13.37
# Train completion:5.23%, time:29 m:54 s, avg loss: 13.18, avg acc:0.09%, last loss: 12.82
# Train completion:5.28%, time:30 m:9 s, avg loss: 13.17, avg acc:0.08%, last loss: 12.69
# Train completion:5.32%, time:30 m:26 s, avg loss: 13.17, avg acc:0.08%, last loss: 12.87
# Train completion:8.14%, time:48 m:26 s, avg loss: 13.00, avg acc:0.05%, last loss: 12.07
# Train completion:8.19%, time:48 m:44 s, avg loss: 13.00, avg acc:0.05%, last loss: 12.14
# Train completion:8.23%, time:49 m:1 s, avg loss: 13.00, avg acc:0.05%, last loss: 12.92
# Train completion:8.28%, time:49 m:19 s, avg loss: 12.99, avg acc:0.05%, last loss: 12.99
# Train completion:8.32%, time:49 m:38 s, avg loss: 12.99, avg acc:0.05%, last loss: 12.32
# Train completion:8.37%, time:49 m:56 s, avg loss: 12.99, avg acc:0.05%, last loss: 12.93
# Train completion:8.41%, time:50 m:13 s, avg loss: 12.99, avg acc:0.05%, last loss: 12.46
# Train completion:8.46%, time:50 m:32 s, avg loss: 12.98, avg acc:0.05%, last loss: 12.15
# Train completion:8.50%, time:50 m:52 s, avg loss: 12.98, avg acc:0.05%, last loss: 12.55
# Train completion:8.54%, time:51 m:11 s, avg loss: 12.98, avg acc:0.05%, last loss: 12.32
# Train completion:8.59%, time:51 m:31 s, avg loss: 12.98, avg acc:0.05%, last loss: 12.56
# Train completion:8.63%, time:51 m:51 s, avg loss: 12.97, avg acc:0.05%, last loss: 12.37
# Train completion:8.68%, time:52 m:9 s, avg loss: 12.97, avg acc:0.05%, last loss: 12.44
# Train completion:8.72%, time:52 m:27 s, avg loss: 12.97, avg acc:0.05%, last loss: 12.45
# Train completion:8.77%, time:52 m:44 s, avg loss: 12.96, avg acc:0.05%, last loss: 12.51
# Train completion:8.81%, time:53 m:2 s, avg loss: 12.96, avg acc:0.05%, last loss: 12.26
# Train completion:8.86%, time:53 m:19 s, avg loss: 12.96, avg acc:0.05%, last loss: 11.92
# Train completion:8.90%, time:53 m:37 s, avg loss: 12.95, avg acc:0.05%, last loss: 12.23
# Train completion:8.95%, time:53 m:55 s, avg loss: 12.95, avg acc:0.05%, last loss: 12.38
# Train completion:8.99%, time:54 m:12 s, avg loss: 12.95, avg acc:0.05%, last loss: 12.38
# Train completion:9.04%, time:54 m:30 s, avg loss: 12.95, avg acc:0.05%, last loss: 12.52
# Train completion:9.08%, time:54 m:47 s, avg loss: 12.94, avg acc:0.05%, last loss: 12.68
# Train completion:9.13%, time:55 m:5 s, avg loss: 12.94, avg acc:0.05%, last loss: 12.55
# Train completion:9.17%, time:55 m:21 s, avg loss: 12.94, avg acc:0.05%, last loss: 12.13
# Train completion:9.22%, time:55 m:38 s, avg loss: 12.94, avg acc:0.05%, last loss: 12.40
# Train completion:9.26%, time:55 m:55 s, avg loss: 12.93, avg acc:0.05%, last loss: 12.33
# Train completion:9.31%, time:56 m:12 s, avg loss: 12.93, avg acc:0.05%, last loss: 12.24
# Train completion:9.35%, time:56 m:29 s, avg loss: 12.93, avg acc:0.05%, last loss: 12.08
# Train completion:9.39%, time:56 m:46 s, avg loss: 12.92, avg acc:0.05%, last loss: 12.04
# Train completion:9.44%, time:57 m:3 s, avg loss: 12.92, avg acc:0.05%, last loss: 11.96
# Train completion:9.48%, time:57 m:20 s, avg loss: 12.92, avg acc:0.05%, last loss: 12.48
# Train completion:9.53%, time:57 m:38 s, avg loss: 12.92, avg acc:0.05%, last loss: 12.37
# Train completion:9.57%, time:57 m:55 s, avg loss: 12.91, avg acc:0.05%, last loss: 12.12
# Train completion:9.62%, time:58 m:13 s, avg loss: 12.91, avg acc:0.05%, last loss: 13.27
# Train completion:9.66%, time:58 m:30 s, avg loss: 12.91, avg acc:0.05%, last loss: 12.71
# Train completion:9.71%, time:58 m:48 s, avg loss: 12.91, avg acc:0.28%, last loss: 12.40
# Train completion:9.75%, time:59 m:5 s, avg loss: 12.90, avg acc:0.28%, last loss: 12.58
# Train completion:9.80%, time:59 m:22 s, avg loss: 12.90, avg acc:0.27%, last loss: 12.08
# Train completion:9.84%, time:59 m:39 s, avg loss: 12.90, avg acc:0.27%, last loss: 12.53
# Train completion:9.89%, time:59 m:57 s, avg loss: 12.90, avg acc:0.27%, last loss: 12.14
# Train completion:9.93%, time:60 m:14 s, avg loss: 12.89, avg acc:0.27%, last loss: 13.01
# Train completion:9.98%, time:60 m:32 s, avg loss: 12.89, avg acc:0.27%, last loss: 12.86
# Train completion:10.02%, time:60 m:49 s, avg loss: 12.89, avg acc:0.27%, last loss: 12.26
# Train completion:10.07%, time:61 m:6 s, avg loss: 12.89, avg acc:0.27%, last loss: 12.30
# Train completion:10.11%, time:61 m:24 s, avg loss: 12.88, avg acc:0.27%, last loss: 12.42
# Train completion:10.16%, time:61 m:41 s, avg loss: 12.88, avg acc:0.26%, last loss: 12.29
# Train completion:10.20%, time:61 m:58 s, avg loss: 12.88, avg acc:0.26%, last loss: 12.16
# Train completion:10.25%, time:62 m:15 s, avg loss: 12.88, avg acc:0.26%, last loss: 12.27
# Train completion:10.29%, time:62 m:32 s, avg loss: 12.87, avg acc:0.26%, last loss: 12.11
# Train completion:10.33%, time:62 m:50 s, avg loss: 12.87, avg acc:0.26%, last loss: 12.20
# Train completion:10.38%, time:63 m:8 s, avg loss: 12.87, avg acc:0.26%, last loss: 12.59
# Train completion:10.42%, time:63 m:25 s, avg loss: 12.87, avg acc:0.26%, last loss: 11.81
# Train completion:10.47%, time:63 m:43 s, avg loss: 12.86, avg acc:0.26%, last loss: 12.19
# Train completion:10.51%, time:64 m:0 s, avg loss: 12.86, avg acc:0.26%, last loss: 12.49
# Train completion:10.56%, time:64 m:17 s, avg loss: 12.86, avg acc:0.25%, last loss: 11.96
# Train completion:10.60%, time:64 m:34 s, avg loss: 12.86, avg acc:0.25%, last loss: 11.89
# Train completion:10.65%, time:64 m:51 s, avg loss: 12.86, avg acc:0.25%, last loss: 12.06
# Train completion:10.69%, time:65 m:9 s, avg loss: 12.85, avg acc:0.25%, last loss: 12.36
# Train completion:10.74%, time:65 m:27 s, avg loss: 12.85, avg acc:0.25%, last loss: 12.28
# Train completion:10.78%, time:65 m:44 s, avg loss: 12.85, avg acc:0.25%, last loss: 12.23
# Train completion:10.83%, time:66 m:1 s, avg loss: 12.85, avg acc:0.25%, last loss: 12.33
# Train completion:10.87%, time:66 m:18 s, avg loss: 12.84, avg acc:0.25%, last loss: 12.32
# Train completion:10.92%, time:66 m:34 s, avg loss: 12.84, avg acc:0.25%, last loss: 12.39
# Train completion:10.96%, time:66 m:51 s, avg loss: 12.84, avg acc:0.24%, last loss: 12.43
# Train completion:11.01%, time:67 m:8 s, avg loss: 12.84, avg acc:0.24%, last loss: 12.54
# Train completion:11.05%, time:67 m:26 s, avg loss: 12.83, avg acc:0.24%, last loss: 12.45
# Train completion:11.10%, time:67 m:43 s, avg loss: 12.83, avg acc:0.48%, last loss: 11.86
# Train completion:11.14%, time:68 m:1 s, avg loss: 12.83, avg acc:0.48%, last loss: 12.44
# Train completion:11.18%, time:68 m:18 s, avg loss: 12.83, avg acc:0.48%, last loss: 12.16
# Train completion:11.23%, time:68 m:35 s, avg loss: 12.82, avg acc:0.48%, last loss: 12.04
# Train completion:11.27%, time:68 m:53 s, avg loss: 12.82, avg acc:0.48%, last loss: 12.50
# Train completion:11.32%, time:69 m:11 s, avg loss: 12.82, avg acc:0.47%, last loss: 11.78
# Train completion:11.36%, time:69 m:29 s, avg loss: 12.82, avg acc:0.47%, last loss: 12.35
# Train completion:11.41%, time:69 m:46 s, avg loss: 12.81, avg acc:0.47%, last loss: 12.36
# Train completion:11.45%, time:70 m:4 s, avg loss: 12.81, avg acc:0.47%, last loss: 12.10
# Train completion:11.50%, time:70 m:21 s, avg loss: 12.81, avg acc:0.47%, last loss: 12.37
# Train completion:11.54%, time:70 m:41 s, avg loss: 12.81, avg acc:0.47%, last loss: 11.86
# Train completion:11.59%, time:71 m:0 s, avg loss: 12.80, avg acc:0.46%, last loss: 12.41
# Train completion:11.63%, time:71 m:20 s, avg loss: 12.80, avg acc:0.46%, last loss: 12.24
# Train completion:11.68%, time:71 m:39 s, avg loss: 12.80, avg acc:0.46%, last loss: 12.40
# Train completion:11.72%, time:71 m:58 s, avg loss: 12.80, avg acc:0.46%, last loss: 12.40
# Train completion:11.77%, time:72 m:14 s, avg loss: 12.80, avg acc:0.46%, last loss: 11.82
# Train completion:11.81%, time:72 m:31 s, avg loss: 12.79, avg acc:0.45%, last loss: 12.08
# Train completion:11.86%, time:72 m:49 s, avg loss: 12.79, avg acc:0.45%, last loss: 11.95
# Train completion:11.90%, time:73 m:6 s, avg loss: 12.79, avg acc:0.45%, last loss: 12.10
# Train completion:11.95%, time:73 m:24 s, avg loss: 12.79, avg acc:0.45%, last loss: 12.05
# Train completion:11.99%, time:73 m:42 s, avg loss: 12.78, avg acc:0.45%, last loss: 12.73
# Train completion:12.03%, time:73 m:59 s, avg loss: 12.78, avg acc:0.45%, last loss: 12.05
# Train completion:12.08%, time:74 m:17 s, avg loss: 12.78, avg acc:0.44%, last loss: 11.68
# Train completion:12.12%, time:74 m:34 s, avg loss: 12.78, avg acc:0.44%, last loss: 11.99
# Train completion:12.17%, time:74 m:52 s, avg loss: 12.77, avg acc:0.44%, last loss: 12.30
# Train completion:12.21%, time:75 m:10 s, avg loss: 12.77, avg acc:0.44%, last loss: 11.94
# Train completion:12.26%, time:75 m:28 s, avg loss: 12.77, avg acc:0.44%, last loss: 12.50
# Train completion:12.30%, time:75 m:45 s, avg loss: 12.77, avg acc:0.44%, last loss: 11.58
# Train completion:12.35%, time:76 m:2 s, avg loss: 12.77, avg acc:0.43%, last loss: 12.13
# Train completion:12.39%, time:76 m:18 s, avg loss: 12.76, avg acc:0.43%, last loss: 11.91
# Train completion:12.44%, time:76 m:35 s, avg loss: 12.76, avg acc:0.43%, last loss: 12.05
# Train completion:12.48%, time:76 m:52 s, avg loss: 12.76, avg acc:0.43%, last loss: 11.80
# Train completion:12.53%, time:77 m:10 s, avg loss: 12.76, avg acc:0.43%, last loss: 11.87
# Train completion:12.57%, time:77 m:28 s, avg loss: 12.75, avg acc:0.43%, last loss: 11.85
# Train completion:12.62%, time:77 m:46 s, avg loss: 12.75, avg acc:0.43%, last loss: 12.43
# Train completion:12.66%, time:78 m:4 s, avg loss: 12.75, avg acc:0.42%, last loss: 11.58
# Train completion:12.71%, time:78 m:21 s, avg loss: 12.75, avg acc:0.42%, last loss: 11.55
# Train completion:12.75%, time:78 m:37 s, avg loss: 12.74, avg acc:0.42%, last loss: 12.23
# Train completion:12.80%, time:78 m:53 s, avg loss: 12.74, avg acc:0.42%, last loss: 12.04
# Train completion:12.84%, time:79 m:9 s, avg loss: 12.74, avg acc:0.42%, last loss: 12.22
# Train completion:12.88%, time:79 m:26 s, avg loss: 12.74, avg acc:0.42%, last loss: 11.97
# Train completion:12.93%, time:79 m:42 s, avg loss: 12.73, avg acc:0.42%, last loss: 12.06
# Train completion:12.97%, time:79 m:59 s, avg loss: 12.73, avg acc:0.41%, last loss: 12.01
# Train completion:13.02%, time:80 m:17 s, avg loss: 12.73, avg acc:0.41%, last loss: 11.75
# Train completion:13.06%, time:80 m:35 s, avg loss: 12.73, avg acc:0.41%, last loss: 12.17
# Train completion:13.11%, time:80 m:53 s, avg loss: 12.73, avg acc:0.41%, last loss: 11.75
# Train completion:13.15%, time:81 m:12 s, avg loss: 12.72, avg acc:0.41%, last loss: 11.73
# Train completion:13.20%, time:81 m:31 s, avg loss: 12.72, avg acc:0.41%, last loss: 12.31
# Train completion:13.24%, time:81 m:50 s, avg loss: 12.72, avg acc:0.41%, last loss: 11.75
# Train completion:13.29%, time:82 m:8 s, avg loss: 12.72, avg acc:0.40%, last loss: 11.97
# Train completion:13.33%, time:82 m:25 s, avg loss: 12.71, avg acc:0.40%, last loss: 12.18
# Train completion:13.38%, time:82 m:42 s, avg loss: 12.71, avg acc:0.40%, last loss: 12.09
# Train completion:13.42%, time:83 m:1 s, avg loss: 12.71, avg acc:0.40%, last loss: 11.71
# Train completion:13.47%, time:83 m:19 s, avg loss: 12.71, avg acc:0.40%, last loss: 11.92
# Train completion:13.51%, time:83 m:37 s, avg loss: 12.70, avg acc:0.40%, last loss: 12.13
# Train completion:13.56%, time:83 m:55 s, avg loss: 12.70, avg acc:0.40%, last loss: 12.25
# Train completion:13.60%, time:84 m:14 s, avg loss: 12.70, avg acc:0.39%, last loss: 12.31
# Train completion:15.03%, time:93 m:33 s, avg loss: 12.62, avg acc:0.51%, last loss: 12.10
# Train completion:15.08%, time:93 m:52 s, avg loss: 12.62, avg acc:0.50%, last loss: 12.29
# Train completion:15.12%, time:94 m:10 s, avg loss: 12.62, avg acc:0.50%, last loss: 11.57
# Train completion:15.17%, time:94 m:29 s, avg loss: 12.62, avg acc:0.50%, last loss: 11.83
# Train completion:15.21%, time:94 m:47 s, avg loss: 12.61, avg acc:0.50%, last loss: 11.62
# Train completion:15.26%, time:95 m:6 s, avg loss: 12.61, avg acc:0.50%, last loss: 12.26
# Train completion:15.30%, time:95 m:24 s, avg loss: 12.61, avg acc:0.56%, last loss: 11.80
# Train completion:15.35%, time:95 m:41 s, avg loss: 12.61, avg acc:0.58%, last loss: 11.88
# Train completion:15.39%, time:95 m:59 s, avg loss: 12.61, avg acc:0.58%, last loss: 11.50
# Train completion:15.43%, time:96 m:17 s, avg loss: 12.60, avg acc:0.58%, last loss: 12.35
# Train completion:15.48%, time:96 m:35 s, avg loss: 12.60, avg acc:0.58%, last loss: 12.18
# Train completion:15.52%, time:96 m:53 s, avg loss: 12.60, avg acc:0.58%, last loss: 11.76
# Train completion:15.57%, time:97 m:11 s, avg loss: 12.60, avg acc:0.57%, last loss: 11.92
# Train completion:15.61%, time:97 m:29 s, avg loss: 12.59, avg acc:0.57%, last loss: 11.45
# Train completion:15.66%, time:97 m:48 s, avg loss: 12.59, avg acc:0.57%, last loss: 11.25
# Train completion:15.70%, time:98 m:5 s, avg loss: 12.59, avg acc:0.57%, last loss: 12.14
# Train completion:15.75%, time:98 m:23 s, avg loss: 12.59, avg acc:0.57%, last loss: 11.75
# Train completion:15.79%, time:98 m:41 s, avg loss: 12.58, avg acc:0.57%, last loss: 11.92
# Train completion:15.84%, time:98 m:58 s, avg loss: 12.58, avg acc:0.56%, last loss: 11.19
# Train completion:15.88%, time:99 m:16 s, avg loss: 12.58, avg acc:0.56%, last loss: 12.22
# Train completion:15.93%, time:99 m:34 s, avg loss: 12.58, avg acc:0.56%, last loss: 11.42
# Train completion:15.97%, time:99 m:53 s, avg loss: 12.58, avg acc:0.56%, last loss: 12.04
# Train completion:16.02%, time:100 m:11 s, avg loss: 12.57, avg acc:0.56%, last loss: 11.64
# Train completion:16.06%, time:100 m:29 s, avg loss: 12.57, avg acc:0.56%, last loss: 11.83
# Train completion:16.11%, time:100 m:47 s, avg loss: 12.57, avg acc:0.56%, last loss: 11.74
# Train completion:16.15%, time:101 m:4 s, avg loss: 12.57, avg acc:0.55%, last loss: 11.71
# Train completion:16.20%, time:101 m:22 s, avg loss: 12.56, avg acc:0.55%, last loss: 12.34
# Train completion:16.24%, time:101 m:40 s, avg loss: 12.56, avg acc:0.55%, last loss: 11.38
# Train completion:16.28%, time:101 m:58 s, avg loss: 12.56, avg acc:0.55%, last loss: 11.86
# Train completion:16.33%, time:102 m:16 s, avg loss: 12.56, avg acc:0.55%, last loss: 12.04
# Train completion:17.76%, time:111 m:26 s, avg loss: 12.49, avg acc:0.65%, last loss: 11.75
# Train completion:17.81%, time:111 m:43 s, avg loss: 12.49, avg acc:0.65%, last loss: 11.59
# Train completion:17.85%, time:111 m:59 s, avg loss: 12.48, avg acc:0.65%, last loss: 11.68
# Train completion:17.90%, time:112 m:16 s, avg loss: 12.48, avg acc:0.65%, last loss: 11.48
# Train completion:17.94%, time:112 m:34 s, avg loss: 12.48, avg acc:0.65%, last loss: 11.36
# Train completion:17.98%, time:112 m:51 s, avg loss: 12.48, avg acc:0.65%, last loss: 11.98
# Train completion:18.03%, time:113 m:9 s, avg loss: 12.48, avg acc:0.65%, last loss: 11.41
# Train completion:18.07%, time:113 m:27 s, avg loss: 12.47, avg acc:0.64%, last loss: 11.54
# Train completion:18.12%, time:113 m:46 s, avg loss: 12.47, avg acc:0.64%, last loss: 11.49
# Train completion:18.16%, time:114 m:4 s, avg loss: 12.47, avg acc:0.64%, last loss: 11.43
# Train completion:18.21%, time:114 m:23 s, avg loss: 12.47, avg acc:0.64%, last loss: 11.97
# Train completion:18.25%, time:114 m:42 s, avg loss: 12.46, avg acc:0.64%, last loss: 11.28
# Train completion:18.30%, time:115 m:1 s, avg loss: 12.46, avg acc:0.64%, last loss: 11.77
# Train completion:18.34%, time:115 m:19 s, avg loss: 12.46, avg acc:0.63%, last loss: 11.91
# Train completion:18.39%, time:115 m:37 s, avg loss: 12.46, avg acc:0.63%, last loss: 11.39
# Train completion:18.43%, time:115 m:55 s, avg loss: 12.46, avg acc:0.63%, last loss: 11.66
# Train completion:18.48%, time:116 m:13 s, avg loss: 12.45, avg acc:0.63%, last loss: 11.84
# Train completion:18.52%, time:116 m:31 s, avg loss: 12.45, avg acc:0.63%, last loss: 11.11
# Train completion:18.57%, time:116 m:49 s, avg loss: 12.45, avg acc:0.63%, last loss: 11.20
# Train completion:18.61%, time:117 m:8 s, avg loss: 12.45, avg acc:0.62%, last loss: 11.41
# Train completion:18.66%, time:117 m:26 s, avg loss: 12.45, avg acc:0.62%, last loss: 12.65
# Train completion:18.70%, time:117 m:44 s, avg loss: 12.44, avg acc:0.62%, last loss: 11.40
# Train completion:18.75%, time:118 m:2 s, avg loss: 12.44, avg acc:0.62%, last loss: 11.87
# Train completion:18.79%, time:118 m:20 s, avg loss: 12.44, avg acc:0.62%, last loss: 11.53
# Train completion:18.83%, time:118 m:38 s, avg loss: 12.44, avg acc:0.62%, last loss: 11.35
# Train completion:18.88%, time:118 m:56 s, avg loss: 12.43, avg acc:0.62%, last loss: 11.38
# Train completion:18.92%, time:119 m:15 s, avg loss: 12.43, avg acc:0.61%, last loss: 11.67
# Train completion:18.97%, time:119 m:33 s, avg loss: 12.43, avg acc:0.66%, last loss: 11.63
# Train completion:19.01%, time:119 m:52 s, avg loss: 12.43, avg acc:0.66%, last loss: 11.98
# Train completion:19.06%, time:120 m:10 s, avg loss: 12.43, avg acc:0.66%, last loss: 11.48
# Train completion:19.10%, time:120 m:28 s, avg loss: 12.42, avg acc:0.66%, last loss: 11.69
# Train completion:19.15%, time:120 m:46 s, avg loss: 12.42, avg acc:0.65%, last loss: 11.60
# Train completion:19.19%, time:121 m:5 s, avg loss: 12.42, avg acc:0.65%, last loss: 11.33
# Train completion:19.24%, time:121 m:23 s, avg loss: 12.42, avg acc:0.65%, last loss: 11.37
# Train completion:19.28%, time:121 m:41 s, avg loss: 12.42, avg acc:0.65%, last loss: 11.71
# Train completion:19.33%, time:122 m:0 s, avg loss: 12.41, avg acc:0.65%, last loss: 11.06
# Train completion:19.37%, time:122 m:18 s, avg loss: 12.41, avg acc:0.65%, last loss: 11.41
# Train completion:19.42%, time:122 m:37 s, avg loss: 12.41, avg acc:0.65%, last loss: 12.05
# Train completion:19.46%, time:122 m:55 s, avg loss: 12.41, avg acc:0.64%, last loss: 11.33
# Train completion:19.51%, time:123 m:14 s, avg loss: 12.41, avg acc:0.64%, last loss: 11.81
# Train completion:19.55%, time:123 m:32 s, avg loss: 12.40, avg acc:0.64%, last loss: 11.95
# Train completion:19.60%, time:123 m:50 s, avg loss: 12.40, avg acc:0.64%, last loss: 11.13
# Train completion:19.64%, time:124 m:9 s, avg loss: 12.40, avg acc:0.64%, last loss: 11.44
# Train completion:19.68%, time:124 m:28 s, avg loss: 12.40, avg acc:0.64%, last loss: 12.40
# Train completion:19.73%, time:124 m:46 s, avg loss: 12.39, avg acc:0.63%, last loss: 11.23
# Train completion:19.77%, time:125 m:5 s, avg loss: 12.39, avg acc:0.63%, last loss: 11.33
# Train completion:19.82%, time:125 m:23 s, avg loss: 12.39, avg acc:0.68%, last loss: 11.56
# Train completion:19.86%, time:125 m:40 s, avg loss: 12.39, avg acc:0.68%, last loss: 11.68
# Train completion:19.91%, time:125 m:59 s, avg loss: 12.39, avg acc:0.67%, last loss: 11.64
# Train completion:19.95%, time:126 m:18 s, avg loss: 12.38, avg acc:0.67%, last loss: 11.37
# Train completion:20.00%, time:126 m:36 s, avg loss: 12.38, avg acc:0.67%, last loss: 11.80
# Train completion:20.04%, time:126 m:54 s, avg loss: 12.38, avg acc:0.67%, last loss: 11.50
# Train completion:20.09%, time:127 m:13 s, avg loss: 12.38, avg acc:0.67%, last loss: 11.28
# Train completion:20.13%, time:127 m:31 s, avg loss: 12.38, avg acc:0.67%, last loss: 11.93
# Train completion:20.18%, time:127 m:49 s, avg loss: 12.38, avg acc:0.67%, last loss: 11.17
# Train completion:20.22%, time:128 m:7 s, avg loss: 12.37, avg acc:0.66%, last loss: 11.15
# Train completion:20.27%, time:128 m:25 s, avg loss: 12.37, avg acc:0.66%, last loss: 11.59
# Train completion:20.31%, time:128 m:43 s, avg loss: 12.37, avg acc:0.66%, last loss: 11.84
# Train completion:20.36%, time:129 m:2 s, avg loss: 12.37, avg acc:0.66%, last loss: 12.26
# Train completion:20.40%, time:129 m:20 s, avg loss: 12.37, avg acc:0.66%, last loss: 11.25
# Train completion:20.45%, time:129 m:38 s, avg loss: 12.36, avg acc:0.66%, last loss: 11.30
# Train completion:20.49%, time:129 m:56 s, avg loss: 12.36, avg acc:0.66%, last loss: 11.73
# Train completion:20.53%, time:130 m:14 s, avg loss: 12.36, avg acc:0.65%, last loss: 11.73
# Train completion:20.58%, time:130 m:32 s, avg loss: 12.36, avg acc:0.65%, last loss: 11.16
# Train completion:20.62%, time:130 m:50 s, avg loss: 12.36, avg acc:0.67%, last loss: 10.60
# Train completion:20.67%, time:131 m:9 s, avg loss: 12.35, avg acc:0.67%, last loss: 11.90
# Train completion:20.71%, time:131 m:27 s, avg loss: 12.35, avg acc:0.69%, last loss: 11.28
# Train completion:20.76%, time:131 m:46 s, avg loss: 12.35, avg acc:0.69%, last loss: 11.14
# Train completion:20.80%, time:132 m:3 s, avg loss: 12.35, avg acc:0.69%, last loss: 11.70
# Train completion:20.85%, time:132 m:21 s, avg loss: 12.35, avg acc:0.69%, last loss: 11.52
# Train completion:20.89%, time:132 m:39 s, avg loss: 12.34, avg acc:0.69%, last loss: 11.73
# Train completion:20.94%, time:132 m:58 s, avg loss: 12.34, avg acc:0.68%, last loss: 11.22
# Train completion:20.98%, time:133 m:16 s, avg loss: 12.34, avg acc:0.68%, last loss: 12.08
# Train completion:21.03%, time:133 m:33 s, avg loss: 12.34, avg acc:0.68%, last loss: 11.37
# Train completion:21.07%, time:133 m:51 s, avg loss: 12.34, avg acc:0.68%, last loss: 11.33
# Train completion:21.12%, time:134 m:10 s, avg loss: 12.33, avg acc:0.68%, last loss: 11.72
# Train completion:21.16%, time:134 m:28 s, avg loss: 12.33, avg acc:0.68%, last loss: 11.23
# Train completion:21.21%, time:134 m:46 s, avg loss: 12.33, avg acc:0.68%, last loss: 10.88
# Train completion:21.25%, time:135 m:5 s, avg loss: 12.33, avg acc:0.67%, last loss: 11.20
# Train completion:21.30%, time:135 m:23 s, avg loss: 12.33, avg acc:0.67%, last loss: 11.65
# Train completion:21.34%, time:135 m:42 s, avg loss: 12.32, avg acc:0.67%, last loss: 11.08
# Train completion:21.38%, time:136 m:0 s, avg loss: 12.32, avg acc:0.67%, last loss: 11.38
# Train completion:21.43%, time:136 m:17 s, avg loss: 12.32, avg acc:0.67%, last loss: 11.77
# Train completion:21.47%, time:136 m:35 s, avg loss: 12.32, avg acc:0.67%, last loss: 11.80
# Train completion:21.52%, time:136 m:53 s, avg loss: 12.32, avg acc:0.67%, last loss: 11.12
# Train completion:21.56%, time:137 m:12 s, avg loss: 12.31, avg acc:0.66%, last loss: 11.53
# Train completion:21.61%, time:137 m:31 s, avg loss: 12.31, avg acc:0.66%, last loss: 11.78
# Train completion:21.65%, time:137 m:48 s, avg loss: 12.31, avg acc:0.66%, last loss: 11.28
# Train completion:21.70%, time:138 m:7 s, avg loss: 12.31, avg acc:0.66%, last loss: 10.81
# Train completion:21.74%, time:138 m:25 s, avg loss: 12.31, avg acc:0.66%, last loss: 11.46
# Train completion:21.79%, time:138 m:42 s, avg loss: 12.30, avg acc:0.66%, last loss: 11.54
# Train completion:21.83%, time:139 m:1 s, avg loss: 12.30, avg acc:0.66%, last loss: 11.16
# Train completion:21.88%, time:139 m:19 s, avg loss: 12.30, avg acc:0.65%, last loss: 10.53
# Train completion:21.92%, time:139 m:38 s, avg loss: 12.30, avg acc:0.65%, last loss: 11.31
# Train completion:21.97%, time:139 m:56 s, avg loss: 12.30, avg acc:0.65%, last loss: 11.55
# Train completion:22.01%, time:140 m:13 s, avg loss: 12.29, avg acc:0.65%, last loss: 11.50
# Train completion:22.06%, time:140 m:31 s, avg loss: 12.29, avg acc:0.65%, last loss: 11.33
# Train completion:22.10%, time:140 m:50 s, avg loss: 12.29, avg acc:0.65%, last loss: 11.30
# Train completion:22.15%, time:141 m:8 s, avg loss: 12.29, avg acc:0.65%, last loss: 11.19
# Train completion:22.19%, time:141 m:26 s, avg loss: 12.29, avg acc:0.65%, last loss: 11.39
# Train completion:22.23%, time:141 m:45 s, avg loss: 12.28, avg acc:0.64%, last loss: 11.00
# Train completion:22.28%, time:142 m:4 s, avg loss: 12.28, avg acc:0.64%, last loss: 11.10
# Train completion:22.32%, time:142 m:23 s, avg loss: 12.28, avg acc:0.64%, last loss: 11.53
# Train completion:22.37%, time:142 m:38 s, avg loss: 12.28, avg acc:0.68%, last loss: 11.38
# Train completion:22.41%, time:142 m:57 s, avg loss: 12.28, avg acc:0.68%, last loss: 11.64
# Train completion:22.46%, time:143 m:15 s, avg loss: 12.27, avg acc:0.68%, last loss: 11.39
# Train completion:22.50%, time:143 m:33 s, avg loss: 12.27, avg acc:0.68%, last loss: 11.01
# Train completion:22.55%, time:143 m:52 s, avg loss: 12.27, avg acc:0.67%, last loss: 11.30
# Train completion:22.59%, time:144 m:10 s, avg loss: 12.27, avg acc:0.67%, last loss: 11.78
# Train completion:22.64%, time:144 m:29 s, avg loss: 12.27, avg acc:0.67%, last loss: 11.95
# Train completion:22.68%, time:144 m:46 s, avg loss: 12.26, avg acc:0.67%, last loss: 11.01
# Train completion:22.73%, time:145 m:4 s, avg loss: 12.26, avg acc:0.67%, last loss: 11.69
# Train completion:22.77%, time:145 m:21 s, avg loss: 12.26, avg acc:0.67%, last loss: 11.73
# Train completion:22.82%, time:145 m:39 s, avg loss: 12.26, avg acc:0.67%, last loss: 11.30
# Train completion:22.86%, time:145 m:58 s, avg loss: 12.26, avg acc:0.67%, last loss: 11.66
# Train completion:22.91%, time:146 m:16 s, avg loss: 12.26, avg acc:0.66%, last loss: 11.32
# Train completion:22.95%, time:146 m:35 s, avg loss: 12.25, avg acc:0.66%, last loss: 11.34
# Train completion:23.00%, time:146 m:52 s, avg loss: 12.25, avg acc:0.66%, last loss: 11.47
# Train completion:23.04%, time:147 m:10 s, avg loss: 12.25, avg acc:0.68%, last loss: 12.09
# Train completion:23.08%, time:147 m:27 s, avg loss: 12.25, avg acc:0.68%, last loss: 10.74
# Train completion:23.13%, time:147 m:44 s, avg loss: 12.25, avg acc:0.68%, last loss: 11.30
# Train completion:23.17%, time:148 m:3 s, avg loss: 12.24, avg acc:0.71%, last loss: 10.91
# Train completion:23.22%, time:148 m:22 s, avg loss: 12.24, avg acc:0.71%, last loss: 10.99
# Train completion:8.95%, time:87 m:39 s, avg loss: 6.06, avg acc:459.55%, last loss: 5.86
# Train completion:8.99%, time:87 m:55 s, avg loss: 6.06, avg acc:460.15%, last loss: 6.11
# Train completion:9.04%, time:88 m:12 s, avg loss: 6.06, avg acc:460.59%, last loss: 6.45
# Train completion:9.08%, time:88 m:29 s, avg loss: 6.06, avg acc:460.49%, last loss: 6.62
# Train completion:9.13%, time:88 m:48 s, avg loss: 6.05, avg acc:461.03%, last loss: 5.84
# Train completion:9.17%, time:89 m:5 s, avg loss: 6.05, avg acc:461.17%, last loss: 6.55
# Train completion:9.22%, time:89 m:23 s, avg loss: 6.05, avg acc:461.12%, last loss: 6.03
# Train completion:9.26%, time:89 m:40 s, avg loss: 6.05, avg acc:461.64%, last loss: 5.87
# Train completion:9.31%, time:90 m:0 s, avg loss: 6.05, avg acc:461.49%, last loss: 6.01
# Train completion:9.35%, time:90 m:18 s, avg loss: 6.05, avg acc:461.96%, last loss: 6.35
# Train completion:9.39%, time:90 m:36 s, avg loss: 6.05, avg acc:462.57%, last loss: 5.31
# Train completion:9.44%, time:90 m:54 s, avg loss: 6.05, avg acc:462.61%, last loss: 5.72
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [12], in <cell line: 6>()
#      25 _, pred=output.topk(1,dim=1)
#      27 loss.backward()
# ---> 28 optimizer.step()
#      29 lr_decay.step()
#      31 last_loss=loss.item()
#
# File ~\Anaconda3\lib\site-packages\torch\optim\lr_scheduler.py:65, in _LRScheduler.__init__.<locals>.with_counter.<locals>.wrapper(*args, **kwargs)
#      63 instance._step_count += 1
#      64 wrapped = func.__get__(instance, cls)
# ---> 65 return wrapped(*args, **kwargs)
#
# File ~\Anaconda3\lib\site-packages\torch\optim\optimizer.py:88, in Optimizer._hook_for_profile.<locals>.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#      86 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#      87 with torch.autograd.profiler.record_function(profile_name):
# ---> 88     return func(*args, **kwargs)
#
# File ~\Anaconda3\lib\site-packages\torch\autograd\grad_mode.py:27, in _DecoratorContextManager.__call__.<locals>.decorate_context(*args, **kwargs)
#      24 @functools.wraps(func)
#      25 def decorate_context(*args, **kwargs):
#      26     with self.clone():
# ---> 27         return func(*args, **kwargs)
#
# File ~\Anaconda3\lib\site-packages\torch\optim\adamw.py:145, in AdamW.step(self, closure)
#     142         # record the step after step update
#     143         state_steps.append(state['step'])
# --> 145     F.adamw(params_with_grad,
#     146             grads,
#     147             exp_avgs,
#     148             exp_avg_sqs,
#     149             max_exp_avg_sqs,
#     150             state_steps,
#     151             amsgrad=amsgrad,
#     152             beta1=beta1,
#     153             beta2=beta2,
#     154             lr=group['lr'],
#     155             weight_decay=group['weight_decay'],
#     156             eps=group['eps'],
#     157             maximize=group['maximize'])
#     159 return loss
#
# File ~\Anaconda3\lib\site-packages\torch\optim\_functional.py:143, in adamw(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     140 bias_correction2 = 1 - beta2 ** step
#     142 # Decay the first and second moment running average coefficient
# --> 143 exp_avg.mul_(beta1).add_(grad, alpha=1 - beta1)
#     144 exp_avg_sq.mul_(beta2).addcmul_(grad, grad, value=1 - beta2)
#     145 if amsgrad:
#     146     # Maintains the maximum of all 2nd moment running avg. till now
#
# KeyboardInterrupt:

# %%
save_model_path=r"C:\Users\mihnea.andrei\Python scripts\ViT_Google_FB\saved_weights"
save_model_file="\ViT-ParallelLayer_scale_init_Block,embed_dim=%d,depth=%d,num_heads=%d,mlp_ratio=%d,train_loss=%.4f,train_accs=%.2f%%.pt"%(embed_dim,depth,num_heads,mlp_ratio,np.mean(train_losses),100*np.mean(train_accs))

torch.save(model_fit,save_model_path+save_model_file)

# %%
plt.figure(figsize=(10,5))
plt.title("ViT_GOOG-FB training losses")
plt.plot(train_losses,label="train losses")
plt.xlabel("iterations")
plt.ylabel("loss")
plt.legend()
plt.show()

# %%
train_avg_accs=100*np.cumsum(train_accs)/list(range(len(train_accs)))
plt.figure(figsize=(10,5))
plt.title("ViT_GOOG-FB cumulative training average")
plt.plot(train_avg_accs,label="train accuracies")
plt.xlabel("iterations")
plt.ylabel("accuracy")
plt.legend()
plt.show()
# Out:
# C:\Users\mihnea.andrei\AppData\Local\Temp\ipykernel_11696\1358325896.py:1: RuntimeWarning: divide by zero encountered in true_divide
#   train_avg_accs=100*np.cumsum(train_accs)/list(range(len(train_accs)))
